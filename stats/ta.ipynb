# %%
# %run common.ipynb

# %%
np.random.seed(3)
random.seed(3)

# %%
####### Global notebook configs #######

# Toggle for enabling/disabling the 
# decorator
if measure_time.enabled:
    print("* measure_time is enabled ")

# specify the folder path and files name 
dataset_file_path = os.path.join('../datasets', 'cities.csv')
print(f"* the selected dataset is located at: {dataset_file_path}")

# select the nb of cities you want from the dataset
np_of_cities = 50
print(f"* {np_of_cities} will be used from the dataset")

# select the number of truck you wish to divide the workload
truck_nb = 5
print(f"* {truck_nb} will be used to deliver the goods")

# choose an average speed that suit your needs (here 51.3 km/h)
average_speed = 51.3
print(f"* the average speed is : {average_speed} km/h")

# tabu related conf 
num_iterations = 3000
tabu_list_size = 1000
print(f"* the tabu list size is : {tabu_list_size} and it will iterate {num_iterations} times")

# multistart related conf
num_starts = 10
print(f"* multistart factor : {num_starts}")

####### ####### ####### ####### #######
# Out:
# * measure_time is enabled
# * the selected dataset is located at: ../datasets/cities.csv
# * 50 will be used from the dataset
# * 5 will be used to deliver the goods
# * the average speed is : 51.3 km/h
# * the tabu list size is : 1000 and it will iterate 3000 times
# * multistart factor : 10

# %% [markdown]
# # City Generator
#
# this part contains the folowing logic: we first retrieve data from a dataset and later construct a sample from it that contain the cities name, the ZIP Code, the population count and longitude|latitude

# %%
# disable performance profiling for this section 
measure_time.enabled = False

citiesTuple = read_csv_to_tuple(dataset_file_path)
citiesSample = sample_N_from_tuple(citiesTuple, np_of_cities)

# display the map with the selected cities
plot_cities(citiesSample)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c348da9acb2931caa3b1ad59c5f78927 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c348da9acb2931caa3b1ad59c5f78927&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c348da9acb2931caa3b1ad59c5f78927 = L.map(
#                 &quot;map_c348da9acb2931caa3b1ad59c5f78927&quot;,
#                 {
#                     center: [47.24929776, 6.83407272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc471c3e49e4211be8fea21c4be4cc88 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c348da9acb2931caa3b1ad59c5f78927);
#
#
#             var marker_c3e24aa8d9641f6a41f2c2ad3d9e9c64 = L.marker(
#                 [47.24929776, 6.83407272],
#                 {}
#             ).addTo(map_c348da9acb2931caa3b1ad59c5f78927);
#
#
#         var popup_903f2dd89ea62a8650250f4476c7db74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a310d1712c41076192f0aea56751dd3 = $(`&lt;div id=&quot;html_6a310d1712c41076192f0aea56751dd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cernay-l&#x27;Église&lt;/div&gt;`)[0];
#                 popup_903f2dd89ea62a8650250f4476c7db74.setContent(html_6a310d1712c41076192f0aea56751dd3);
#
#
#
#         marker_c3e24aa8d9641f6a41f2c2ad3d9e9c64.bindPopup(popup_903f2dd89ea62a8650250f4476c7db74)
#         ;
#
#
#
#
#             var marker_8d843ea312ab251b4eaa3c7dc72eeb86 = L.marker(
#                 [45.384684214876, -0.50199900826446],
#                 {}
#             ).addTo(map_c348da9acb2931caa3b1ad59c5f78927);
#
#
#         var popup_d69c134440a33dab00a399ad03aaf161 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d48fc178d0ba99560b89a61c6185801 = $(`&lt;div id=&quot;html_2d48fc178d0ba99560b89a61c6185801&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Allas-Bocage&lt;/div&gt;`)[0];
#                 popup_d69c134440a33dab00a399ad03aaf161.setContent(html_2d48fc178d0ba99560b89a61c6185801);
#
#
#
#         marker_8d843ea312ab251b4eaa3c7dc72eeb86.bindPopup(popup_d69c134440a33dab00a399ad03aaf161)
#         ;
#
#
#
#
#             var marker_6231288bed1df3fdbc555ac22fde6bff = L.marker(
#                 [44.726417297297, 0.60406452702703],
#                 {}
#             ).addTo(map_c348da9acb2931caa3b1ad59c5f78927);
#
#
#         var popup_c99d5f800e72de64b2d814b45d1660e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7064785f455f190594a77637ce10175f = $(`&lt;div id=&quot;html_7064785f455f190594a77637ce10175f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Issigeac&lt;/div&gt;`)[0];
#                 popup_c99d5f800e72de64b2d814b45d1660e7.setContent(html_7064785f455f190594a77637ce10175f);
#
#
#
#         marker_6231288bed1df3fdbc555ac22fde6bff.bindPopup(popup_c99d5f800e72de64b2d814b45d1660e7)
#         ;
#
#
#
#
#             var marker_ca374dca57b7769ca01f611c74557de8 = L.marker(
#                 [48.305416115108, 6.8124869064748],
#                 {}
#             ).addTo(map_c348da9acb2931caa3b1ad59c5f78927);
#
#
#         var popup_2c59b2d884e64174abb62f66519a85e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_398616137e109fd5ab11911d60fe3ced = $(`&lt;div id=&quot;html_398616137e109fd5ab11911d60fe3ced&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Bourgonce&lt;/div&gt;`)[0];
#                 popup_2c59b2d884e64174abb62f66519a85e1.setContent(html_398616137e109fd5ab11911d60fe3ced);
#
#
#
#         marker_ca374dca57b7769ca01f611c74557de8.bindPopup(popup_2c59b2d884e64174abb62f66519a85e1)
#         ;
#
#
#
#
#             var marker_d8e6d7f3d6a7c3bfe7afeb3ae153521b = L.marker(
#                 [49.385179756098, 3.5866173170732],
#                 {}
#             ).addTo(map_c348da9acb2931caa3b1ad59c5f78927);
#
#
#         var popup_6420fc88e9fbf88a795dd53f12f55dec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08abdef47dfacfb4d7fc999ce4ef7108 = $(`&lt;div id=&quot;html_08abdef47dfacfb4d7fc999ce4ef7108&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Saint-Mard&lt;/div&gt;`)[0];
#                 popup_6420fc88e9fbf88a795dd53f12f55dec.setContent(html_08abdef47dfacfb4d7fc999ce4ef7108);
#
#
#
#         marker_d8e6d7f3d6a7c3bfe7afeb3ae153521b.bindPopup(popup_6420fc88e9fbf88a795dd53f12f55dec)
#         ;
#
#
#
#
#             var marker_e997823957195df1392bffc8e709c799 = L.marker(

# %% [markdown]
# # location generator
# The purpose of this staged is to generate a series of city names along with their respective longitude and latitude coordinates. It achieves this by extracting the relevant information from a given list of city data

# %%
location = create_location_generator(citiesSample)

# disable performance profiling for this section 
measure_time.enabled = False

for city_name, coordinates in create_location_generator(citiesSample):
    print(f'{city_name}: {coordinates}')
# Out:
# Cernay-l'Église: (6.83407272, 47.24929776)
# Allas-Bocage: (-0.50199900826446, 45.384684214876)
# Issigeac: (0.60406452702703, 44.726417297297)
# La Bourgonce: (6.8124869064748, 48.305416115108)
# Saint-Mard: (3.5866173170732, 49.385179756098)
# Cierp-Gaud: (0.63716026548673, 42.906808141593)
# Saint-Géraud: (0.15511762886598, 44.624371958763)
# Marcillé-Robert: (-1.35109640625, 47.95227203125)
# Sembadel: (3.6860319230769, 45.275283605769)
# Warluis: (2.1584695081967, 49.385440437158)
# Plougastel-Daoulas: (-4.3814217726397, 48.356330366089)
# Gravelotte: (6.0243075409836, 49.110500491803)
# Courgent: (1.6586165151515, 48.896415)
# Conte: (6.0070476271186, 46.750205762712)
# Oëlleville: (6.024512972973, 48.334302342342)
# Saint-Pierre-de-Bat: (-0.21850408163265, 44.670685714286)
# Vatteville: (1.2861831067961, 49.28027961165)
# Saint-Denis-d'Augerons: (0.47065918918919, 48.919018513514)
# Curtil-sous-Buffières: (4.5281553900709, 46.401401985816)
# Saint-Guinoux: (-1.8927695454545, 48.580484090909)
# Uzech: (1.386475210084, 44.591520420168)
# Heudreville-sur-Eure: (1.1834519745223, 49.131022866242)
# Bar-sur-Aube: (4.7149740490797, 48.232359631902)
# Billé: (-1.2548991119691, 48.300863011583)
# Saint-Martin-le-Vinoux: (5.7152886516854, 45.218441348315)
# Linzeux: (2.2015701960784, 50.344042352941)
# Saint-Georges-du-Rosay: (0.52251412790698, 48.201487093023)
# Servais: (3.3442882857143, 49.618675142857)
# Maruéjols-lès-Gardon: (4.13744, 44.005087222222)
# Bréauté: (0.40536055045872, 49.627296880734)
# Marnay-sur-Marne: (5.2367646923077, 48.014281384615)
# Saint-Michel-de-Vax: (1.8034871428571, 44.111535584416)
# Dannevoux: (5.2339790647482, 49.305563884892)
# Le Frasnois: (5.8913142307692, 46.632879692308)
# Boncourt: (3.9543927272727, 49.620752272727)
# Oron: (6.4836225, 48.90218075)
# Levis: (3.330279, 47.66224425)
# Weinbourg: (7.4321952542373, 48.869673559322)
# Villiers-en-Lieu: (4.9002885869565, 48.666123913043)
# Tessel: (-0.56827679245283, 49.149571886792)
# Durrenbach: (7.7683288764045, 48.89772752809)
# Locqueltas: (-2.7612552222222, 47.772515)
# Poinson-lès-Fayl: (5.6017630337079, 47.746508651685)
# Jaignes: (3.083894122807, 48.986765)
# Cleebourg: (7.8912248765432, 48.992749506173)
# Saint-Saturnin-de-Lenne: (3.021780137931, 44.411956413793)
# Lacenas: (4.6417277966102, 45.98528440678)
# Chapelle-Viviers: (0.73245122641509, 46.472462264151)
# Champagny-en-Vanoise: (6.7649764954683, 45.454590332326)
# Crèvec½ur-sur-l'Escaut: (3.2691303144654, 50.079839748428)

# %% [markdown]
# # time matrix generator
#
# this part calculate a time matrix for a set of cities based on their geographic coordinates.

# %%
@measure_time
def calculate_time_matrix(generator) -> Dict[str, Dict[str, float]]:
    time_matrix = {}  # Create an empty dictionary to store the time matrix
    city_coords = []  # Create an empty list to store city names and coordinates
    
    # Iterate over each city name and coordinates from the generator and 
    # append the city name and coordinates as a tuple to city_coords
    for city_name, coordinates in generator:
        city_coords.append((city_name, coordinates)) 
    
    # Iterate over the city name and coordinates using enumerate
    for i, (city1, coords1) in enumerate(city_coords):
        
        # Create an empty dictionary for each city in the time matrix
        time_matrix[city1] = {}
        
        # Iterate over the city name and coordinates again
        for j, (city2, coords2) in enumerate(city_coords):  
            if i == j:
                # Set the time between a city and itself to 0.0
                time_matrix[city1][city2] = 0.0 
            else:
                # Calculate the geodesic distance between two coordinates
                distance = geodesic(coords1, coords2).kilometers
                # Store the time in the time matrix
                time_matrix[city1][city2] = distance / average_speed 
    
    return time_matrix

# %%
"""

The traffic matrix generator applies a random factor to the times 
in order to simulate the increased time it would take to travel from 
city A to city B due to traffic conditions. 

"""
@measure_time
def generate_traffic_matrix(time_matrix):
    traffic_matrix = {}

    for city_a, times in time_matrix.items():
        traffic_matrix[city_a] = {}

        for city_b, time in times.items():
            if city_a == city_b:
                traffic_matrix[city_a][city_b] = 1.0  # Assuming no traffic within the same city
            else:
                traffic_matrix[city_a][city_b] = np.random.uniform(1.0, 1.5) * time
    
    return traffic_matrix

# %%
# disable performance profiling for this section 
measure_time.enabled = False

time_matrix = calculate_time_matrix(
    create_location_generator(citiesSample)
)

traffic_matrix = generate_traffic_matrix(time_matrix)

# %% [markdown]
# # tabu algorithm

# %%
def tabu_search(time_matrix, num_iterations, tabu_list_size, start_town=None, progress_enable = True):
    # Initialize the tabu list as an empty set
    tabu_list = set()
    # Generate an initial random solution
    if start_town is None:
        best_route = list(time_matrix.keys())
        np.random.shuffle(best_route)
    else:
        best_route = list(time_matrix.keys())
        best_route.remove(start_town)
        best_route.insert(0, start_town)
    best_time = calculate_total_time(best_route, time_matrix)

    # Create a progress bar using tqdm
    if progress_enable: 
        progress_bar = tqdm(
            total=num_iterations, 
            desc="Tabu Search", 
            unit="iteration", 
        )

    # Start the iterations
    for _ in range(num_iterations):
        # Find the best neighboring solution
        neighbors = generate_neighbors(best_route, tabu_list)
        
        # [hack] Check if neighbors list is empty 
        if not neighbors:
            if progress_enable: 
                progress_bar.update(num_iterations - progress_bar.n)  # Force progress to 100%
            continue
        
        best_neighbor = min(neighbors, key=lambda x: calculate_total_time(x, time_matrix))

        # Update the best solution if the neighbor is an improvement
        neighbor_time = calculate_total_time(best_neighbor, time_matrix)
        if neighbor_time < best_time:
            best_route = best_neighbor
            best_time = neighbor_time

        # Add the best neighbor to the tabu list
        tabu_list.add(tuple(best_neighbor))
        # Remove the oldest solution from the tabu list if it exceeds the tabu list size
        if len(tabu_list) > tabu_list_size:
            tabu_list.remove(next(iter(tabu_list)))

        # Update the progress bar
        if progress_enable: 
            progress_bar.update(1)

    # Append the first town to the best route to complete the cycle
    best_route.append(best_route[0])
    best_time += time_matrix[best_route[-2]][best_route[0]]

    # Close the progress bar
    if progress_enable: 
        progress_bar.close()

    return best_route, best_time


def calculate_total_time(route, time_matrix):
    total_time = 0.0
    num_cities = len(route)
    for i in range(num_cities - 1):
        current_city = route[i]
        next_city = route[i + 1]
        total_time += time_matrix[current_city][next_city]
    return total_time


def generate_neighbors(route, tabu_list):
    route = np.array(route)
    tabu_list = set(map(tuple, tabu_list))
    num_cities = len(route)
    neighbors = []
    for i in range(1, num_cities):
        for j in range(i + 1, num_cities):
            neighbor = np.concatenate((route[:i], route[i:j][::-1], route[j:]))
            if tuple(neighbor) not in tabu_list:
                neighbors.append(neighbor.tolist())
    return neighbors

# %%
# without constrain 
best_route, best_time = tabu_search(time_matrix, num_iterations, tabu_list_size)
pprint_the_output(best_time, best_route)
plot_cities(citiesSample, best_route)
# Out:
# Tabu Search: 100%|████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:47<00:00, 62.79iteration/s]
# Best time: 108.0432696734068 h
# Best Route: Oëlleville -> Oron -> Gravelotte -> Dannevoux -> Villiers-en-Lieu -> Marnay-sur-Marne -> Bar-sur-Aube -> Levis -> Jaignes -> Saint-Mard -> Boncourt -> Servais -> Crèvec½ur-sur-l'Escaut -> Linzeux -> Warluis -> Courgent -> Vatteville -> Heudreville-sur-Eure -> Saint-Denis-d'Augerons -> Bréauté -> Tessel -> Saint-Guinoux -> Plougastel-Daoulas -> Locqueltas -> Marcillé-Robert -> Billé -> Saint-Georges-du-Rosay -> Chapelle-Viviers -> Allas-Bocage -> Saint-Pierre-de-Bat -> Saint-Géraud -> Issigeac -> Cierp-Gaud -> Uzech -> Saint-Michel-de-Vax -> Saint-Saturnin-de-Lenne -> Maruéjols-lès-Gardon -> Sembadel -> Curtil-sous-Buffières -> Lacenas -> Saint-Martin-le-Vinoux -> Champagny-en-Vanoise -> Le Frasnois -> Conte -> Poinson-lès-Fayl -> Cernay-l'Église -> La Bourgonce -> Weinbourg -> Durrenbach -> Cleebourg -> Oëlleville
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d799b2579509f177447622b3714adf51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d799b2579509f177447622b3714adf51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d799b2579509f177447622b3714adf51 = L.map(
#                 &quot;map_d799b2579509f177447622b3714adf51&quot;,
#                 {
#                     center: [47.24929776, 6.83407272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16006fea680f50cc05158dc542146ff3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d799b2579509f177447622b3714adf51);
#
#
#             var marker_ab96256d36fed04987febe3e0b9b2469 = L.marker(
#                 [48.334302342342, 6.024512972973],
#                 {}
#             ).addTo(map_d799b2579509f177447622b3714adf51);
#
#
#             var div_icon_43fad24aac7f5882d86b64d1d995a7fe = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e1\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_ab96256d36fed04987febe3e0b9b2469.setIcon(div_icon_43fad24aac7f5882d86b64d1d995a7fe);
#
#
#         var popup_ca3bfd36959294ae92572fcd17c33afc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28c2fe66715c9761fa2811e544edb5b9 = $(`&lt;div id=&quot;html_28c2fe66715c9761fa2811e544edb5b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Oëlleville&lt;/div&gt;`)[0];
#                 popup_ca3bfd36959294ae92572fcd17c33afc.setContent(html_28c2fe66715c9761fa2811e544edb5b9);
#
#
#
#         marker_ab96256d36fed04987febe3e0b9b2469.bindPopup(popup_ca3bfd36959294ae92572fcd17c33afc)
#         ;
#
#
#
#
#             var poly_line_3366ee77ee7bb74fe8abbf10b0d810e0 = L.polyline(
#                 [[48.334302342342, 6.024512972973], [48.90218075, 6.4836225]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_d799b2579509f177447622b3714adf51);
#
#
#             poly_line_3366ee77ee7bb74fe8abbf10b0d810e0.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1: Oëlleville -&gt; Oron
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7379db1f73024aebb92cdd84192d3517 = L.marker(
#                 [48.90218075, 6.4836225],
#                 {}
#             ).addTo(map_d799b2579509f177447622b3714adf51);
#
#
#             var div_icon_6e0312b60dab2b367ea6fd206dc2c729 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e2\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_7379db1f73024aebb92cdd84192d3517.setIcon(div_icon_6e0312b60dab2b367ea6fd206dc2c729);
#
#
#         var popup_fb52a2efc6293f407184c314de1d3a03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae0479363a8a9a754be6fd16d3bba2f0 = $(`&lt;div id=&quot;html_ae0479363a8a9a754be6fd16d3bba2f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Oron&lt;/div&gt;`)[0];
#                 popup_fb52a2efc6293f407184c314de1d3a03.setContent(html_ae0479363a8a9a754be6fd16d3bba2f0);
#
#
#
#         marker_7379db1f73024aebb92cdd84192d3517.bindPopup(popup_fb52a2efc6293f407184c314de1d3a03)
#         ;
#
#
#
#
#             var poly_line_cba854531dd59834b09d6418b755a39b = L.polyline(
#                 [[48.90218075, 6.4836225], [49.110500491803, 6.0243075409836]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null,

# %%
# with time constrain 
best_route, best_time = tabu_search(traffic_matrix, num_iterations, tabu_list_size)
pprint_the_output(best_time, best_route)
plot_cities(citiesSample, best_route)
# Out:
# Tabu Search: 100%|████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:47<00:00, 62.88iteration/s]
# Best time: 157.68596689442737 h
# Best Route: Cleebourg -> Durrenbach -> Weinbourg -> La Bourgonce -> Oëlleville -> Oron -> Gravelotte -> Villiers-en-Lieu -> Bar-sur-Aube -> Levis -> Curtil-sous-Buffières -> Lacenas -> Sembadel -> Saint-Saturnin-de-Lenne -> Maruéjols-lès-Gardon -> Saint-Martin-le-Vinoux -> Champagny-en-Vanoise -> Cernay-l'Église -> Conte -> Le Frasnois -> Poinson-lès-Fayl -> Marnay-sur-Marne -> Dannevoux -> Boncourt -> Saint-Mard -> Jaignes -> Servais -> Crèvec½ur-sur-l'Escaut -> Linzeux -> Warluis -> Courgent -> Heudreville-sur-Eure -> Vatteville -> Bréauté -> Tessel -> Saint-Denis-d'Augerons -> Saint-Georges-du-Rosay -> Chapelle-Viviers -> Issigeac -> Uzech -> Saint-Michel-de-Vax -> Cierp-Gaud -> Saint-Géraud -> Saint-Pierre-de-Bat -> Allas-Bocage -> Saint-Guinoux -> Billé -> Plougastel-Daoulas -> Locqueltas -> Marcillé-Robert -> Cleebourg
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2eaa552e755838de0917c51f5501be9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2eaa552e755838de0917c51f5501be9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2eaa552e755838de0917c51f5501be9f = L.map(
#                 &quot;map_2eaa552e755838de0917c51f5501be9f&quot;,
#                 {
#                     center: [47.24929776, 6.83407272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4fb50b6b41a71643084575f9b6ce053 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2eaa552e755838de0917c51f5501be9f);
#
#
#             var marker_6bd4d4bb21b1b69454e477c155309dcc = L.marker(
#                 [48.992749506173, 7.8912248765432],
#                 {}
#             ).addTo(map_2eaa552e755838de0917c51f5501be9f);
#
#
#             var div_icon_9f571edc605829f693c5003cbaaaae28 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e1\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_6bd4d4bb21b1b69454e477c155309dcc.setIcon(div_icon_9f571edc605829f693c5003cbaaaae28);
#
#
#         var popup_b63f3e21495da8af0c584da8c24bab87 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1eb0185d6441b27548b40c400dd1a1b1 = $(`&lt;div id=&quot;html_1eb0185d6441b27548b40c400dd1a1b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cleebourg&lt;/div&gt;`)[0];
#                 popup_b63f3e21495da8af0c584da8c24bab87.setContent(html_1eb0185d6441b27548b40c400dd1a1b1);
#
#
#
#         marker_6bd4d4bb21b1b69454e477c155309dcc.bindPopup(popup_b63f3e21495da8af0c584da8c24bab87)
#         ;
#
#
#
#
#             var poly_line_9afffab65b05453c7914bb1bbe421c03 = L.polyline(
#                 [[48.992749506173, 7.8912248765432], [48.89772752809, 7.7683288764045]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_2eaa552e755838de0917c51f5501be9f);
#
#
#             poly_line_9afffab65b05453c7914bb1bbe421c03.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1: Cleebourg -&gt; Durrenbach
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6192ab09f42b2ad9e5c27aedaf8907e1 = L.marker(
#                 [48.89772752809, 7.7683288764045],
#                 {}
#             ).addTo(map_2eaa552e755838de0917c51f5501be9f);
#
#
#             var div_icon_ba138f5334d56a87d90a765880b588a7 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e2\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_6192ab09f42b2ad9e5c27aedaf8907e1.setIcon(div_icon_ba138f5334d56a87d90a765880b588a7);
#
#
#         var popup_3d806bb55b1ba2197b3299dd7180a176 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f7b240b8b702528b7bde66124bd72aa = $(`&lt;div id=&quot;html_8f7b240b8b702528b7bde66124bd72aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Durrenbach&lt;/div&gt;`)[0];
#                 popup_3d806bb55b1ba2197b3299dd7180a176.setContent(html_8f7b240b8b702528b7bde66124bd72aa);
#
#
#
#         marker_6192ab09f42b2ad9e5c27aedaf8907e1.bindPopup(popup_3d806bb55b1ba2197b3299dd7180a176)
#         ;
#
#
#
#
#             var poly_line_20afb7531c10bd6a8907b0e36a6305c3 = L.polyline(
#                 [[48.89772752809, 7.7683288764045], [48.869673559322, 7.4321952542373]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b

# %% [markdown]
# # construct sub matrix for the truck repartition

# %%
def split_into_trucks(time_matrix, num_trucks):
    # Convert the time matrix to a numpy array
    towns = list(time_matrix.keys())
    time_array = np.array([[time_matrix[town1][town2] for town2 in towns] for town1 in towns])
    
    # Apply k-means clustering
    kmeans = KMeans(n_clusters=num_trucks, random_state=0, n_init=10).fit(time_array)
    labels = kmeans.labels_
    
    # Find the index of the first town in the time matrix
    first_town_index = towns.index(towns[0])
    
    # Create time matrices for each truck
    trucks = []
    for i in range(num_trucks):
        # Filter towns based on the label or if it's the first town
        truck_towns = [towns[j] for j in range(len(towns)) if labels[j] == i or j == first_town_index]
        truck_time_matrix = {town: {truck_town: time_matrix[town][truck_town] for truck_town in truck_towns} for town in truck_towns}
        trucks.append(truck_time_matrix)
    
    return trucks

def filter_cities_by_truck(citiesSample, truck):
    town_list = list(truck.keys())
    filtered_cities = [city for city in citiesSample if city[4] in town_list]
    return np.array(filtered_cities)


def optimize_trucks(trucks, map_obj, use_traffic_matrix=False):
    for i, truck in enumerate(trucks):
        if use_traffic_matrix:
            truck = generate_traffic_matrix(truck)
        best_route, best_time = tabu_search(truck, num_iterations, tabu_list_size, start_town=next(iter(truck)))
            
        print(f"The truck n: {i}")
        pprint_the_output(best_time, best_route)
        plot_cities(filter_cities_by_truck(citiesSample, truck), best_route, map_obj=map_obj, color=color[i])
    
    return map_obj

# %%
# withouth time constrain, only trucks
trucks = split_into_trucks(time_matrix, truck_nb)

map_obj = folium.Map(
    location=[
        float(citiesSample[0][2]), 
        float(citiesSample[0][3])
    ], 
    zoom_start=6)

optimize_trucks(trucks, map_obj)
# Out:
# Tabu Search: 100%|██████████████████████████████████████████████████████████████████████████| 3000/3000 [00:01<00:00, 2994.27iteration/s]
# The truck n: 0
# Best time: 41.87914952975381 h
# Best Route: Cernay-l'Église -> Levis -> Jaignes -> Saint-Mard -> Boncourt -> Servais -> Warluis -> Courgent -> Saint-Georges-du-Rosay -> Saint-Denis-d'Augerons -> Bréauté -> Heudreville-sur-Eure -> Vatteville -> Linzeux -> Crèvec½ur-sur-l'Escaut -> Cernay-l'Église
# Tabu Search: 100%|█████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 18435.23iteration/s]
# The truck n: 1
# Best time: 24.201421266259278 h
# Best Route: Cernay-l'Église -> Curtil-sous-Buffières -> Lacenas -> Sembadel -> Saint-Saturnin-de-Lenne -> Maruéjols-lès-Gardon -> Saint-Martin-le-Vinoux -> Champagny-en-Vanoise -> Cernay-l'Église
# Tabu Search: 100%|█████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 13315.59iteration/s]
# The truck n: 2
# Best time: 42.31188563132243 h
# Best Route: Cernay-l'Église -> Uzech -> Saint-Michel-de-Vax -> Cierp-Gaud -> Issigeac -> Saint-Géraud -> Saint-Pierre-de-Bat -> Allas-Bocage -> Chapelle-Viviers -> Cernay-l'Église
# Tabu Search: 100%|██████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 3108.99iteration/s]
# The truck n: 3
# Best time: 23.070536027437164 h
# Best Route: Cernay-l'Église -> Conte -> Le Frasnois -> Poinson-lès-Fayl -> Marnay-sur-Marne -> Bar-sur-Aube -> Villiers-en-Lieu -> Dannevoux -> Gravelotte -> Oron -> Oëlleville -> La Bourgonce -> Weinbourg -> Durrenbach -> Cleebourg -> Cernay-l'Église
# Tabu Search: 100%|█████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 27300.27iteration/s]
# The truck n: 4
# Best time: 51.23343658911645 h
# Best Route: Cernay-l'Église -> Tessel -> Billé -> Marcillé-Robert -> Saint-Guinoux -> Plougastel-Daoulas -> Locqueltas -> Cernay-l'Église
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aedc604c3cac755305c41258c94c9b3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aedc604c3cac755305c41258c94c9b3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aedc604c3cac755305c41258c94c9b3e = L.map(
#                 &quot;map_aedc604c3cac755305c41258c94c9b3e&quot;,
#                 {
#                     center: [47.24929776, 6.83407272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b07e43c7020a2a04a7bdea0d720904a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aedc604c3cac755305c41258c94c9b3e);
#
#
#             var marker_192864ebddd56e1c26a747aee5254fce = L.marker(
#                 [47.24929776, 6.83407272],
#                 {}
#             ).addTo(map_aedc604c3cac755305c41258c94c9b3e);
#
#
#             var div_icon_40867c81114f15cd4131fc1aed158dfa = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e1\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_192864ebddd56e1c26a747aee5254fce.setIcon(div_icon_40867c81114f15cd4131fc1aed158dfa);
#
#
#         var popup_1735bec5ce3d94a1cb0f9441fc7fef19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2fc16a0779a3e3583bd3b477ceefa8f = $(`&lt;div id=&quot;html_d2fc16a0779a3e3583bd3b477ceefa8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cernay-l&#x27;Église&lt;/div&gt;`)[0];
#                 popup_1735bec5ce3d94a1cb0f9441fc7fef19.setContent(html_d2fc16a0779a3e3583bd3b477ceefa8f);
#
#
#
#         marker_192864ebddd56e1c26a747aee5254fce.bindPopup(popup_1735bec5ce3d94a1cb0f9441fc7fef19)
#         ;
#
#
#
#
#             var poly_line_60fb5825a76fab1f884873579e649449 = L.polyline(
#                 [[47.24929776, 6.83407272], [47.66224425, 3.330279]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;Green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;Green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_aedc604c3cac755305c41258c94c9b3e);
#
#
#             poly_line_60fb5825a76fab1f884873579e649449.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1: Cernay-l&#x27;Église -&gt; Levis
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3b1af2cb02897f5b49b5b81991a66d1e = L.marker(
#                 [47.66224425, 3.330279],
#                 {}
#             ).addTo(map_aedc604c3cac755305c41258c94c9b3e);
#
#
#             var div_icon_4a49ff2901efdc3ea8e56c4f7d563ef6 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e2\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_3b1af2cb02897f5b49b5b81991a66d1e.setIcon(div_icon_4a49ff2901efdc3ea8e56c4f7d563ef6);
#
#
#         var popup_82786eb7b46c2e9a709528f2729970c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a65b75f37a36fe9606cf05ced4d9f2e3 = $(`&lt;div id=&quot;html_a65b75f37a36fe9606cf05ced4d9f2e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Levis&lt;/div&gt;`)[0];
#                 popup_82786eb7b46c2e9a709528f2729970c3.setContent(html_a65b75f37a36fe9606cf05ced4d9f2e3);
#
#
#
#         marker_3b1af2cb02897f5b49b5b81991a66d1e.bindPopup(popup_82786eb7b46c2e9a709528f2729970c3)
#         ;
#
#
#
#
#             var poly_line_b648c6ee21840dca201ebfcbd41c0707 = L.polyline(
#                 [[47.66224425, 3.330279], [48.986765, 3.083894122807]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;Green&quot;, &quot;dashArray&quot;: null,

# %%
# with time constrain and trucks
trucks = split_into_trucks(time_matrix, truck_nb)

map_obj = folium.Map(
    location=[
        float(citiesSample[0][2]), 
        float(citiesSample[0][3])
    ], 
    zoom_start=6)

optimize_trucks(trucks, map_obj)
# Out:
# Tabu Search: 100%|██████████████████████████████████████████████████████████████████████████| 3000/3000 [00:01<00:00, 2935.74iteration/s]
# The truck n: 0
# Best time: 41.87914952975381 h
# Best Route: Cernay-l'Église -> Levis -> Jaignes -> Saint-Mard -> Boncourt -> Servais -> Warluis -> Courgent -> Saint-Georges-du-Rosay -> Saint-Denis-d'Augerons -> Bréauté -> Heudreville-sur-Eure -> Vatteville -> Linzeux -> Crèvec½ur-sur-l'Escaut -> Cernay-l'Église
# Tabu Search: 100%|█████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 18441.93iteration/s]
# The truck n: 1
# Best time: 24.201421266259278 h
# Best Route: Cernay-l'Église -> Curtil-sous-Buffières -> Lacenas -> Sembadel -> Saint-Saturnin-de-Lenne -> Maruéjols-lès-Gardon -> Saint-Martin-le-Vinoux -> Champagny-en-Vanoise -> Cernay-l'Église
# Tabu Search: 100%|█████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 13407.53iteration/s]
# The truck n: 2
# Best time: 42.31188563132243 h
# Best Route: Cernay-l'Église -> Uzech -> Saint-Michel-de-Vax -> Cierp-Gaud -> Issigeac -> Saint-Géraud -> Saint-Pierre-de-Bat -> Allas-Bocage -> Chapelle-Viviers -> Cernay-l'Église
# Tabu Search: 100%|██████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 3108.40iteration/s]
# The truck n: 3
# Best time: 23.070536027437164 h
# Best Route: Cernay-l'Église -> Conte -> Le Frasnois -> Poinson-lès-Fayl -> Marnay-sur-Marne -> Bar-sur-Aube -> Villiers-en-Lieu -> Dannevoux -> Gravelotte -> Oron -> Oëlleville -> La Bourgonce -> Weinbourg -> Durrenbach -> Cleebourg -> Cernay-l'Église
# Tabu Search: 100%|█████████████████████████████████████████████████████████████████████████| 3000/3000 [00:00<00:00, 26105.63iteration/s]
# The truck n: 4
# Best time: 51.23343658911645 h
# Best Route: Cernay-l'Église -> Tessel -> Billé -> Marcillé-Robert -> Saint-Guinoux -> Plougastel-Daoulas -> Locqueltas -> Cernay-l'Église
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4d77fc4f1346c26f2dc5d34e67e3110 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4d77fc4f1346c26f2dc5d34e67e3110&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4d77fc4f1346c26f2dc5d34e67e3110 = L.map(
#                 &quot;map_b4d77fc4f1346c26f2dc5d34e67e3110&quot;,
#                 {
#                     center: [47.24929776, 6.83407272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_287ef9f9b25e8ebf8d695eaa7f0348a1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b4d77fc4f1346c26f2dc5d34e67e3110);
#
#
#             var marker_57d34353d3a5e8878dc27752c2e8e406 = L.marker(
#                 [47.24929776, 6.83407272],
#                 {}
#             ).addTo(map_b4d77fc4f1346c26f2dc5d34e67e3110);
#
#
#             var div_icon_eb18c945f5fdcadb28cce64512a58ae7 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e1\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_57d34353d3a5e8878dc27752c2e8e406.setIcon(div_icon_eb18c945f5fdcadb28cce64512a58ae7);
#
#
#         var popup_01606829d3aa9638b9df86929daa9895 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd2ebd031560e36437d57310466a1415 = $(`&lt;div id=&quot;html_fd2ebd031560e36437d57310466a1415&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cernay-l&#x27;Église&lt;/div&gt;`)[0];
#                 popup_01606829d3aa9638b9df86929daa9895.setContent(html_fd2ebd031560e36437d57310466a1415);
#
#
#
#         marker_57d34353d3a5e8878dc27752c2e8e406.bindPopup(popup_01606829d3aa9638b9df86929daa9895)
#         ;
#
#
#
#
#             var poly_line_52a93ed7b2f86cf016a7bd9c5bc62f54 = L.polyline(
#                 [[47.24929776, 6.83407272], [47.66224425, 3.330279]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;Green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;Green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_b4d77fc4f1346c26f2dc5d34e67e3110);
#
#
#             poly_line_52a93ed7b2f86cf016a7bd9c5bc62f54.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1: Cernay-l&#x27;Église -&gt; Levis
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2caf44426544be6c6362d5af7c1a9034 = L.marker(
#                 [47.66224425, 3.330279],
#                 {}
#             ).addTo(map_b4d77fc4f1346c26f2dc5d34e67e3110);
#
#
#             var div_icon_ce1084211629de24006b310671ea6f5d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e2\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_2caf44426544be6c6362d5af7c1a9034.setIcon(div_icon_ce1084211629de24006b310671ea6f5d);
#
#
#         var popup_0ae85ac067927b1302880b11939f015d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f41fe1fcb48e49967ed597873a985867 = $(`&lt;div id=&quot;html_f41fe1fcb48e49967ed597873a985867&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Levis&lt;/div&gt;`)[0];
#                 popup_0ae85ac067927b1302880b11939f015d.setContent(html_f41fe1fcb48e49967ed597873a985867);
#
#
#
#         marker_2caf44426544be6c6362d5af7c1a9034.bindPopup(popup_0ae85ac067927b1302880b11939f015d)
#         ;
#
#
#
#
#             var poly_line_09157ecca519550c3b04f28b737d4f71 = L.polyline(
#                 [[47.66224425, 3.330279], [48.986765, 3.083894122807]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;Green&quot;, &quot;dashArray&quot;: null,

# %% [markdown]
# # multi start implementation

# %%
def multi_start_optimization(time_matrix, truck_nb, map_obj, num_starts, use_traffic_matrix=False):
    best_routes = []
    best_times = []
    total_times = []
    trucks_list = []

    for i in tqdm(range(num_starts), desc="multistart"):
        time_matrix_shuffled = list(time_matrix.items())
        np.random.shuffle(time_matrix_shuffled)
        time_matrix_shuffled = dict(time_matrix_shuffled)
        
        trucks = split_into_trucks(time_matrix_shuffled, truck_nb)
        trucks_list.append(trucks)
        
        start_routes = []
        start_times = []

        for i, truck in enumerate(trucks):
            if use_traffic_matrix:
                truck = generate_traffic_matrix(truck)
            route, time = tabu_search(truck, num_iterations, tabu_list_size, start_town=next(iter(truck)), progress_enable=False)

            start_routes.append(route)
            start_times.append(time)

        best_routes.append(start_routes)
        best_times.append(start_times)
        total_time = sum(start_times)
        total_times.append(total_time)

    sorted_starts = sorted(range(num_starts), key=lambda k: total_times[k], reverse=True)
        
    for i, truck in enumerate(trucks_list[sorted_starts[-1]]):
        route = [lst for lst in best_routes[sorted_starts[-1]] if list(truck.keys())[1] in lst][0]
        plot_cities(filter_cities_by_truck(citiesSample, truck), route, map_obj=map_obj, color=color[i])
    
    print(f"the best route is: {best_routes[sorted_starts[-1]]}\n")
    print([f"truck{i + 1}: {time} h" for i, time in enumerate(best_times[sorted_starts[-1]])])
    print(f"\n with the slowest truck taking: {max(best_times[sorted_starts[-1]])} h")
    return map_obj

# %%
# with time constrain and trucks
map_obj = folium.Map(
    location=[
        float(citiesSample[0][2]), 
        float(citiesSample[0][3])
    ], 
    zoom_start=6)

multi_start_optimization(traffic_matrix, truck_nb, map_obj, num_starts)
# Out:
# multistart: 100%|████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:24<00:00,  2.46s/it]
# the best route is: [['Saint-Michel-de-Vax', 'Saint-Saturnin-de-Lenne', 'Sembadel', 'Levis', 'Curtil-sous-Buffières', 'Lacenas', 'Saint-Martin-le-Vinoux', 'Maruéjols-lès-Gardon', 'Saint-Michel-de-Vax'], ['Saint-Michel-de-Vax', 'Saint-Georges-du-Rosay', "Saint-Denis-d'Augerons", 'Bréauté', 'Heudreville-sur-Eure', 'Vatteville', 'Courgent', 'Warluis', 'Linzeux', "Crèvec½ur-sur-l'Escaut", 'Servais', 'Boncourt', 'Saint-Mard', 'Jaignes', 'Saint-Michel-de-Vax'], ['Saint-Michel-de-Vax', 'Champagny-en-Vanoise', "Cernay-l'Église", 'La Bourgonce', 'Cleebourg', 'Durrenbach', 'Weinbourg', 'Oron', 'Oëlleville', 'Gravelotte', 'Dannevoux', 'Villiers-en-Lieu', 'Bar-sur-Aube', 'Marnay-sur-Marne', 'Poinson-lès-Fayl', 'Conte', 'Le Frasnois', 'Saint-Michel-de-Vax'], ['Saint-Michel-de-Vax', 'Tessel', 'Billé', 'Saint-Guinoux', 'Plougastel-Daoulas', 'Locqueltas', 'Marcillé-Robert', 'Saint-Michel-de-Vax'], ['Saint-Michel-de-Vax', 'Uzech', 'Cierp-Gaud', 'Saint-Géraud', 'Saint-Pierre-de-Bat', 'Allas-Bocage', 'Chapelle-Viviers', 'Issigeac', 'Saint-Michel-de-Vax']]
#
# ['truck1: 31.872413059803474 h', 'truck2: 46.163752713994924 h', 'truck3: 52.51620710968914 h', 'truck4: 45.19051804940672 h', 'truck5: 27.464077634764234 h']
#
#  with the slowest truck taking: 52.51620710968914 h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62fe8cec998ca650d9d93db195a2bb24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62fe8cec998ca650d9d93db195a2bb24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62fe8cec998ca650d9d93db195a2bb24 = L.map(
#                 &quot;map_62fe8cec998ca650d9d93db195a2bb24&quot;,
#                 {
#                     center: [47.24929776, 6.83407272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00751c2ffc4f5b2db81f51f1f1f029f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_62fe8cec998ca650d9d93db195a2bb24);
#
#
#             var marker_74718a88af5f103c5886e05e0838680b = L.marker(
#                 [44.111535584416, 1.8034871428571],
#                 {}
#             ).addTo(map_62fe8cec998ca650d9d93db195a2bb24);
#
#
#             var div_icon_63f6881ff606e8bb3c7dfc9c18553abb = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e1\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_74718a88af5f103c5886e05e0838680b.setIcon(div_icon_63f6881ff606e8bb3c7dfc9c18553abb);
#
#
#         var popup_e6f6aba9afc142ac2bc4d61f8b86beb1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bf20b4ef5c2155bb269ec07aa573818 = $(`&lt;div id=&quot;html_9bf20b4ef5c2155bb269ec07aa573818&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Saint-Michel-de-Vax&lt;/div&gt;`)[0];
#                 popup_e6f6aba9afc142ac2bc4d61f8b86beb1.setContent(html_9bf20b4ef5c2155bb269ec07aa573818);
#
#
#
#         marker_74718a88af5f103c5886e05e0838680b.bindPopup(popup_e6f6aba9afc142ac2bc4d61f8b86beb1)
#         ;
#
#
#
#
#             var poly_line_4eaa36c0ad7ded0bc32273bd7f3c5958 = L.polyline(
#                 [[44.111535584416, 1.8034871428571], [44.411956413793, 3.021780137931]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;Green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;Green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_62fe8cec998ca650d9d93db195a2bb24);
#
#
#             poly_line_4eaa36c0ad7ded0bc32273bd7f3c5958.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1: Saint-Michel-de-Vax -&gt; Saint-Saturnin-de-Lenne
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_635166fe4ef5d9fdb1a8d059adc83311 = L.marker(
#                 [44.411956413793, 3.021780137931],
#                 {}
#             ).addTo(map_62fe8cec998ca650d9d93db195a2bb24);
#
#
#             var div_icon_491638a4d6b2c750b104d8e49a754df7 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;\n            background-color: #ff5959;\n            color: #ffffff;\n            border-radius: 100%;\n            padding: 20%;\n            text-align: center;\n            font-weight: bold;\n            font-size: auto;\n        \&quot;\u003e2\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [12, 12], &quot;iconSize&quot;: [24, 24]});
#             marker_635166fe4ef5d9fdb1a8d059adc83311.setIcon(div_icon_491638a4d6b2c750b104d8e49a754df7);
#
#
#         var popup_6df2d947704e9f95ea26402555be8c74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4392e09a0646fe7a2bb4520a02a45451 = $(`&lt;div id=&quot;html_4392e09a0646fe7a2bb4520a02a45451&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Saint-Saturnin-de-Lenne&lt;/div&gt;`)[0];
#                 popup_6df2d947704e9f95ea26402555be8c74.setContent(html_4392e09a0646fe7a2bb4520a02a45451);
#
#
#
#         marker_635166fe4ef5d9fdb1a8d059adc83311.bindPopup(popup_6df2d947704e9f95ea26402555be8c74)
#         ;
#
#
#
#
#             var poly_line_9a845cefe73ef3a4e7ab5269d519155d = L.polyline(
#                 [[44.411956413793, 3.021780137931], [45.275283605769, 3.6860319230769]],
#                 {&quot;bubblingMou

# %% [markdown]
# # multi start implementation (with parallelism)

# %%
def multi_start_optimization(time_matrix, truck_nb, map_obj, num_starts, use_traffic_matrix=False, max_threads=4):
    best_routes = []
    best_times = []
    total_times = []
    trucks_list = []

    def optimize_start(start_index):
        time_matrix_shuffled = list(time_matrix.items())
        np.random.shuffle(time_matrix_shuffled)
        time_matrix_shuffled = dict(time_matrix_shuffled)

        trucks = split_into_trucks(time_matrix_shuffled, truck_nb)
        trucks_list.append(trucks)

        start_routes = []
        start_times = []

        for i, truck in enumerate(trucks):
            if use_traffic_matrix:
                truck = generate_traffic_matrix(truck)

            route, time = tabu_search(truck, num_iterations=100, tabu_list_size=100, start_town=next(iter(truck)), progress_enable=False)

            start_routes.append(route)
            start_times.append(time)
            
            progress_bar.update(1)  # Increment the common progress bar

        best_routes.append(start_routes)
        best_times.append(start_times)
        total_time = sum(start_times)
        total_times.append(total_time)

    # Create a single common progress bar
    progress_bar = tqdm(total=num_starts * truck_nb, desc="parallelised multistart", position=0)

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_threads) as executor:
        futures = [executor.submit(optimize_start, i) for i in range(num_starts)]
        concurrent.futures.wait(futures)

    progress_bar.close()  # Close the common progress bar

    sorted_starts = sorted(range(num_starts), key=lambda k: total_times[k], reverse=True)

    for i, truck in enumerate(trucks_list[sorted_starts[-1]]):
        route = [lst for lst in best_routes[sorted_starts[-1]] if list(truck.keys())[1] in lst][0]
        plot_cities(filter_cities_by_truck(citiesSample, truck), route, map_obj=map_obj, color=color[i])

    print(f"the best route is: {best_routes[sorted_starts[-1]]}\n")
    print([f"truck{i + 1}: {time} h" for i, time in enumerate(best_times[sorted_starts[-1]])])
    print(f"\n with the slowest truck taking: {max(best_times[sorted_starts[-1]])} h")
    return map_obj

# %%
# with time constrain and trucks
map_obj = folium.Map(
    location=[
        float(citiesSample[0][2]), 
        float(citiesSample[0][3])
    ], 
    zoom_start=6)

multi_start_optimization(traffic_matrix, truck_nb, map_obj, num_starts)
